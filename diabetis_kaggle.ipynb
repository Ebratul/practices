# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebratul/practices/blob/main/diabetis_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import RobustScaler

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Ebratul/practices/refs/heads/main/diabetes.csv?token=GHSAT0AAAAAADI5JLRRSPX4WEV35IVAINQC2EXQAIA")

# %%
df.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# #diabetes outcome ratio
# "Blues", "coolwarm", "viridis"

# %%
sb.countplot(x='Outcome', data = df, palette='Blues')
sb.set_style("whitegrid")
# Out:
# /tmp/ipython-input-4119361027.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x='Outcome', data = df, palette='Blues')

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Histogram plots

# %%
for i in df.columns:
  plt.title(f"{str(i)} Distribution")
  sb.distplot(df[str(i)], rug = True, norm_hist=True)
  plt.show()
# Out:
# /tmp/ipython-input-1574613169.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df[str(i)], rug = True, norm_hist=True)
# /tmp/ipython-input-1574613169.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df[str(i)], rug = True, norm_hist=True)
# ...

# %% [markdown]
# #Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
input_features = [col for col in df.columns if 'Outcome' not in col]
for col in input_features:
  df[col] = RobustScaler().fit_transform(df[[col]])

# %%
input_features
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0          0.6  0.751515       0.000000        0.37500 -0.239686  0.172043
# 1         -0.4 -0.775758      -0.333333        0.18750 -0.239686 -0.580645
# 2          1.0  1.600000      -0.444444       -0.71875 -0.239686 -0.935484
# 3         -0.4 -0.678788      -0.333333        0.00000  0.499018 -0.419355
# 4         -0.6  0.484848      -1.777778        0.37500  1.080550  1.193548
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.665359  1.235294        1
# 1                 -0.056209  0.117647        0
# 2                  0.783007  0.176471        1
# 3                 -0.537255 -0.470588        0
# 4                  5.007843  0.235294        1

# %%
df.sort_values(by = ['Outcome'], inplace=True, ignore_index=True)
df
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0            2.0  0.678788       0.555556       -0.12500  0.624754 -1.053763
# 1            0.4  0.000000       1.111111       -0.71875 -0.239686  0.225806
# 2            0.4 -0.193939       0.166667        0.09375 -0.239686  0.430108
# 3            0.0 -0.218182      -0.555556        0.03125 -0.239686 -0.645161
# 4            0.8  0.484848       1.000000        0.56250 -0.239686  0.000000
# ..           ...       ...            ...            ...       ...       ...
# 763          1.0  0.193939       1.333333       -0.71875 -0.239686 -3.440860
# 764          1.4  1.236364       0.111111       -0.71875 -0.239686  0.645161
# 765         -0.4  1.745455      -0.666667        0.00000  6.408644 -0.204301
# 766          0.4  1.187879       0.000000       -0.12500  1.135560 -0.666667
# 767          0.8 -0.412121      -4.000000       -0.71875 -0.239686 -0.215054
#
# ...
